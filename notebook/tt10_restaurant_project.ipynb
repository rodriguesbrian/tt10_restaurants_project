# %% [markdown]
# # Projeto Sprint 10

# %% [markdown]
# ## 1. - Introdução ao dataset

# %% [markdown]
# ### 1.1 - Importação bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotly import graph_objects as go
import re

# %% [markdown]
# ### 1.2 - Leitura dataset

# %%
# leitura arquivo csv
rest_data = pd.read_csv('../datasets/rest_data_us_upd.csv')

# %% [markdown]
# ### 1.3 - Primeiras impressões

# %%
# descoberta primeiras linhas
rest_data.head()
# Out:
#       id          object_name                  address  chain object_type  \
# 0  11786  HABITAT COFFEE SHOP   3708 N EAGLE ROCK BLVD  False        Cafe
# 1  11787             REILLY'S        100 WORLD WAY 120  False  Restaurant
# 2  11788       STREET CHURROS  6801 HOLLYWOOD BLVD 253  False   Fast Food
# 3  11789    TRINITI ECHO PARK       1814 W SUNSET BLVD  False  Restaurant
# 4  11790               POLLEN       2100 ECHO PARK AVE  False  Restaurant
#
#    number
# 0      26
# 1       9
# 2      20
# 3      22
# 4      20

# %%
# descoberta informações gerais
rest_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9651 entries, 0 to 9650
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9651 non-null   int64
#  1   object_name  9651 non-null   object
#  2   address      9651 non-null   object
#  3   chain        9648 non-null   object
#  4   object_type  9651 non-null   object
#  5   number       9651 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 452.5+ KB

# %%
# descoberta detalhes
rest_data.describe()
# Out:
#                  id       number
# count   9651.000000  9651.000000
# mean   16611.000000    43.695161
# std     2786.148058    47.622874
# min    11786.000000     1.000000
# 25%    14198.500000    14.000000
# 50%    16611.000000    27.000000
# 75%    19023.500000    46.000000
# max    21436.000000   229.000000

# %% [markdown]
# O dataframe rest_data apresenta a nomeclatura de colunas dentro do padrão snake case.
# Existe a necessidade de conversão no tipo de dado de suas colunas.
# Foram constatados valores ausentes.

# %% [markdown]
# ## 2. - Pré processamento de dados

# %% [markdown]
# ### 2.1 - Ajuste nomenclatura colunas

# %%
# confirmação padrão snake_case
rest_data.columns = rest_data.columns.str.strip().str.lower().str.replace('object_', '')

# %% [markdown]
# ### 2.2 - Ajuste colunas Object type

# %%
# coluna name
rest_data['name'] = rest_data['name'].str.strip().str.lower()

# %%
# coluna address
rest_data['address'] = rest_data['address'].str.strip().str.lower()

# %%
# coluna type
rest_data['type'] = rest_data['type'].str.strip().str.lower()

# %% [markdown]
# ### 2.3 - Ajuste tipos de dados

# %%
# coluna chain
rest_data['chain'] = rest_data['chain'].astype('category')

# %%
# coluna type
rest_data['type'] = rest_data['type'].astype('category')

# %% [markdown]
# ### 2.4 - Validação ausentes

# %%
# descoberta quantidade de valores ausentes
rest_data.isna().sum()
# Out:
# id         0
# name       0
# address    0
# chain      3
# type       0
# number     0
# dtype: int64

# %%
# descoberta linhas coluna chain NAN
nans_names = rest_data[rest_data['chain'].isna()]['name']
rest_data[rest_data['chain'].isna()]
# Out:
#          id                     name               address chain        type  \
# 7408  19194  taqueria los 3 carnales  5000 e whittier blvd   NaN  restaurant
# 7523  19309     jammin jimmy's pizza   1641 firestone blvd   NaN       pizza
# 8648  20434    the lexington theater          129 e 3rd st   NaN  restaurant
#
#       number
# 7408      14
# 7523       1
# 8648      35

# %%
# descoberta se há repetições de nomes
rest_data[rest_data['name'].isin(nans_names)]
# Out:
#          id                     name               address chain        type  \
# 7408  19194  taqueria los 3 carnales  5000 e whittier blvd   NaN  restaurant
# 7523  19309     jammin jimmy's pizza   1641 firestone blvd   NaN       pizza
# 8648  20434    the lexington theater          129 e 3rd st   NaN  restaurant
#
#       number
# 7408      14
# 7523       1
# 8648      35

# %%
# substituição valores ausentes
rest_data['chain'] = rest_data['chain'].fillna(False)

# %% [markdown]
# ### 2.5 - Validação duplicados

# %%
# descoberta valores duplicados
rest_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# descoberta valores duplicados com base na coluna id
print(rest_data[['id', 'name']].duplicated().sum())
print(rest_data[['id', 'address']].duplicated().sum())
print(rest_data[['id', 'chain']].duplicated().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# ## 3. - EDA

# %% [markdown]
# ### 3.1 - Investigue as proporções de vários tipos de estabelecimentos. Construa um gráfico.

# %%
# agrupamento de dados
types = rest_data.groupby('type')['name'].count().reset_index().rename(columns={'type': 'type', 'name': 'quantity'})
types
# Out:
# /tmp/ipython-input-2942169167.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   types = rest_data.groupby('type')['name'].count().reset_index().rename(columns={'type': 'type', 'name': 'quantity'})
#          type  quantity
# 0      bakery       283
# 1         bar       292
# 2        cafe       435
# 3   fast food      1066
# 4       pizza       320
# 5  restaurant      7255

# %%
# criação coluna proporção
total = types['quantity'].sum()
types['proportion'] = (types['quantity'] / total) * 100
types
# Out:
#          type  quantity  proportion
# 0      bakery       283    2.932339
# 1         bar       292    3.025593
# 2        cafe       435    4.507305
# 3   fast food      1066   11.045488
# 4       pizza       320    3.315719
# 5  restaurant      7255   75.173557

# %%
# criação gráfico pizza
proportion_types_pizza = go.Figure(data=[go.Pie(labels=types['type'], values=types['quantity'])])
proportion_types_pizza.update_layout(
    title='Establishment types in LA',
    legend=dict(
        title='Types',
        x=1,
        y=0.5
    ),
    width=1000,
    height=500
)
proportion_types_pizza.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3d7f72ba-2f00-4079-b8a7-6510b652ebaa" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d7f72ba-2f00-4079-b8a7-6510b652ebaa")) {                    Plotly.newPlot(                        "3d7f72ba-2f00-4079-b8a7-6510b652ebaa",                        [{"labels":["bakery","bar","cafe","fast food","pizza","restaurant"],"values":[283,292,435,1066,320,7255],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorb ...

# %%
# construção gráfico de barras horizontal
plt.figure(figsize=(12,6))
sns.barplot(data=types, x='proportion', y='type', hue='type')
plt.title('Establishment types in LA')
plt.ylabel('Types')
plt.xlabel('Proportion (%)')
plt.xlim(0, 100)
plt.show()

# %% [markdown]
# Com grande maioria, os Restaurantes lideram os tipos de estabelecimentos em LA(75%).
#
# Logo em seguida, Fast Foods (11%) e Cafés (4,5%)
#
# Para os demais, ficam muito equiparados entre Pizzarias, Bares e Padarias (3%).

# %% [markdown]
# ### 3.2 - Investigue as proporções de estabelecimentos de rede e não. Construa um gráfico.

# %%
# agrupamento dados
is_chain = rest_data.groupby('chain')['name'].count().reset_index().rename(columns={'chain': 'answers', 'name': 'quantity'})
is_chain
# Out:
# /tmp/ipython-input-4291357240.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   answers  quantity
# 0   False      5975
# 1    True      3676

# %%
# criação coluna proportion
is_chain['proportion'] = (is_chain['quantity'] / total) * 100
is_chain
# Out:
#   answers  quantity  proportion
# 0   False      5975   61.910683
# 1    True      3676   38.089317

# %%
# criação gráfico pizza
proportion_chain_pizza = go.Figure(data=[go.Pie(labels=is_chain['answers'], values=is_chain['proportion'])])
proportion_chain_pizza
proportion_chain_pizza.update_layout(
    title='Is the Establishment part of a chain?',
    legend=dict(
        title='Answers',
        x=1,
        y=0.5
    ),
    width=1000,
    height=500
)
proportion_chain_pizza.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="76ceeb2e-f6ea-49a3-8eb4-997e87e4bce3" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76ceeb2e-f6ea-49a3-8eb4-997e87e4bce3")) {                    Plotly.newPlot(                        "76ceeb2e-f6ea-49a3-8eb4-997e87e4bce3",                        [{"labels":[false,true],"values":[61.91068283079474,38.08931716920526],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}} ...

# %%
# criação gráfico barras horizontal
plt.figure(figsize=(12,6))
sns.barplot(data=is_chain, x='proportion', y='answers', hue='answers')
plt.title('Is the Establishment part of a chain?')
plt.show()

# %% [markdown]
# A maioria dos estabelecimentos listados pertencem não pertencem a uma rede (62% x 38%).

# %% [markdown]
# ### 3.3 - Qual tipo de estabelecimento é típico para redes?

# %%
# filtro chain
chain_data = rest_data[rest_data['chain'] == True]
chain_data
# Out:
#          id                      name                          address chain  \
# 8     11794                abc donuts  3027 n san fernando rd unit 103  True
# 10    11796             el pollo loco               5319 w sunset blvd  True
# 11    11797         poong nyun bakery        928 s western ave ste 109  True
# 12    11798  emc restaurant group llc            3500 w 6th st ste 101  True
# 14    11800         cuscatleca bakery            2501 w sunset blvd #a  True
# ...     ...                       ...                              ...   ...
# 9629  21415            jucuapa bakery             2810 james wood blvd  True
# 9636  21422            chipotle #3094          6719 la tijera blvd a-b  True
# 9639  21425                mcdonald's               1800 s western ave  True
# 9648  21434               juicy wingz              6741 hollywood blvd  True
# 9650  21436              cafe sprouts      1300 s san pedro st ste 111  True
#
#             type  number
# 8      fast food       1
# 10    restaurant      38
# 11        bakery      17
# 12    restaurant     133
# 14        bakery      26
# ...          ...     ...
# 9629      bakery      10
# 9636  restaurant      47
# 9639   fast food     135
# 9648   fast food      15
# 9650  restaurant      19
#
# [3676 rows x 6 columns]

# %%
# agrupamento dados
chain_types = chain_data.groupby('type')['name'].count().reset_index().rename(columns={'type': 'type', 'name': 'quantity'})
chain_types
# Out:
# /tmp/ipython-input-1269817926.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#          type  quantity
# 0      bakery       283
# 1         bar        77
# 2        cafe       266
# 3   fast food       605
# 4       pizza       153
# 5  restaurant      2292

# %%
# criação coluna proporção
total_chain = chain_types['quantity'].sum()
chain_types['proportion'] = (chain_types['quantity'] / total_chain) * 100
chain_types
# Out:
#          type  quantity  proportion
# 0      bakery       283    7.698585
# 1         bar        77    2.094668
# 2        cafe       266    7.236126
# 3   fast food       605   16.458107
# 4       pizza       153    4.162133
# 5  restaurant      2292   62.350381

# %%
# criação gráfico pizza
chain_types_pizza = go.Figure(data=[go.Pie(labels=chain_types['type'], values=chain_types['proportion'])])
chain_types_pizza.update_layout(
    title='Establishments types in LA parts of a chain',
    legend=dict(
        title='Types',
        x=1,
        y=0.5
    ),
    width=1000,
    height=500
)
chain_types_pizza.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eabb67fa-d091-4e95-ae06-05acf15d463a" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eabb67fa-d091-4e95-ae06-05acf15d463a")) {                    Plotly.newPlot(                        "eabb67fa-d091-4e95-ae06-05acf15d463a",                        [{"labels":["bakery","bar","cafe","fast food","pizza","restaurant"],"values":[7.698585418933623,2.0946681175190425,7.236126224156692,16.45810663764962,4.162132752992384,62.35038084874864],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"soli ...

# %%
# criação gráfico barras horizontal
plt.figure(figsize=(12,6))
sns.barplot(data=chain_types, x='proportion', y='type', hue='type')
plt.title('Establishments types in LA parts of a chain')
plt.xlabel('Proportion (%)')
plt.ylabel('Types')
plt.xlim(0,100)
plt.show()

# %% [markdown]
# Com grande maioria, os Restaurantes lideram nos tipos de estabelecimentos parte de uma rede (62%).
#
# Logo em seguida, Fast Foods (16.5%).
#
# Após, equiparados Padarias e Cafés (7%).
#
# Para os demais,  Pizzarias (4%) e Bares (2%).

# %% [markdown]
# ### 3.4 - O que caracteriza redes: muitos estabelecimentos com um pequeno número de assentos ou poucos estabelecimentos com muitos assentos?

# %%
# criação gráfico dispersão
plt.figure(figsize=(12,6))
sns.histplot(data=chain_data['number'])
plt.title('Histogram Capacity per chain Establishment')
plt.xlabel('Capacity')
plt.ylabel('Establishments')
plt.show()

# %% [markdown]
# Estabelecimentos por rede podem ser caracterizados como muitos estabelecimentos com poucos assentos e poucos estabelecimentos com muitos assentos.

# %% [markdown]
# ### 3.5 - Determine o número médio de assentos para cada tipo de restaurante. Em média, qual tipo de restaurante tem o maior número de assentos? Construa gráficos.

# %%
# filtro dados
is_restaurant = rest_data[rest_data['type'] == 'restaurant']
is_restaurant
# Out:
#          id               name                       address  chain  \
# 1     11787           reilly's             100 world way 120  False
# 3     11789  triniti echo park            1814 w sunset blvd  False
# 4     11790             pollen            2100 echo park ave  False
# 5     11791     the spot grill           10004 national blvd  False
# 6     11792                cpk             100 world way 126  False
# ...     ...                ...                           ...    ...
# 9643  21429        divine dips          601 s los angeles st  False
# 9645  21431         saint marc  10250 santa monica blvd 1025  False
# 9646  21432    hall of justice              217 w temple ave  False
# 9647  21433        fin-melrose              5750 melrose ave  False
# 9650  21436       cafe sprouts   1300 s san pedro st ste 111   True
#
#             type  number
# 1     restaurant       9
# 3     restaurant      22
# 4     restaurant      20
# 5     restaurant      14
# 6     restaurant     100
# ...          ...     ...
# 9643  restaurant      25
# 9645  restaurant     225
# 9646  restaurant     122
# 9647  restaurant      93
# 9650  restaurant      19
#
# [7255 rows x 6 columns]

# %%
# agrupamento dados
sits_per_restaurant = rest_data.groupby('chain')['number'].mean().reset_index()
sits_per_restaurant
# Out:
# /tmp/ipython-input-3592026515.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#    chain     number
# 0  False  46.156653
# 1   True  39.694233

# %%
# gráfico boxplot
plt.figure(figsize=(12,6))
sns.boxplot(data=is_restaurant, y='number', x='chain', hue='chain')
plt.title('Boxplot Restaurants types sits')
plt.xlabel('Type')
plt.ylabel('Quantity')
plt.show()

# %%
# gráfico barras
plt.figure(figsize=(12,6))
sns.barplot(data=is_restaurant, x='chain', y='number', hue='chain')
plt.title('Average sits per Restaurant type in LA')
plt.xlabel('Types')
plt.ylabel('Average sits')
plt.show()

# %% [markdown]
# Os restaurantes que não pertencem a uma rede possuem maior número médio de assentos (46 x 40)

# %% [markdown]
# ### 3.6 - Coloque os dados dos nomes das ruas da coluna address em uma coluna separada.

# %%
# uso de expressão regular para criação de nova coluna
rest_data['street'] = (
    rest_data['address']
    # remoção número inicial
    .str.replace(r'^\d+\s+', '', regex=True)
    # remoção complementos finais
    .str.replace(r'\s+\d+.*$', '', regex=True)
    # remoção espaços em branco
    .str.strip()
)
rest_data['street']
# Out:
# 0        n eagle rock blvd
# 1                world way
# 2           hollywood blvd
# 3            w sunset blvd
# 4            echo park ave
#                ...
# 9646          w temple ave
# 9647           melrose ave
# 9648        hollywood blvd
# 9649       s spring st ste
# 9650    s san pedro st ste
# Name: street, Length: 9651, dtype: object

# %% [markdown]
# ### 3.7 - Construa um gráfico de dez ruas com o maior número de restaurantes.

# %%
# agrupamento dados
restaurants_per_street = is_restaurant.groupby('address')['name'].count().reset_index().rename(columns={'address': 'address', 'name': 'quantity'}).sort_values('quantity', ascending=False)
streets_with_most_restaurants = restaurants_per_street.iloc[:10]
streets_with_most_restaurants
# Out:
#                        address  quantity
# 4427  5151 state university dr         8
# 5498             700 world way         7
# 3677             400 world way         6
# 4615         545 s figueroa st         6
# 1916  2025 avenue of the stars         6
# 2597             300 world way         5
# 6325        900 w olympic blvd         5
# 4919             600 world way         5
# 3389       3607 trousdale pkwy         5
# 5230        6360 w sunset blvd         4

# %%
# construção gráfico barras
plt.figure(figsize=(12,6))
sns.barplot(data=streets_with_most_restaurants, x='address', y='quantity', hue='address')
plt.title('Addresses with most restaurants')
plt.xlabel('Addresses')
plt.ylabel('Restaurant quantity')
plt.legend('')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 5151 State University Dr (8) o ranking de endereços com maior número de restaurantes. Seguido por 700 World Way (7).
#
# Em seguida, 400 World Way, 545 S Figueroa St e 2025 Avenue of the Stars (6).
#
# Finalizando com 300 World Way, 900 W Olympic Blvd, 600 World Way, 3607 Trousdale Pkwy (5) e 6360 W Sunset Blvd (4)

# %% [markdown]
# ### 3.8 - Encontre o número de ruas que têm apenas um restaurante.

# %%
# agrupamento dados
streets_with_one_restaurant = restaurants_per_street[restaurants_per_street['quantity'] == 1]
streets_with_one_restaurant
print(f'Existem {streets_with_one_restaurant.shape[0]} ruas com apenas um restaurante.')
# Out:
# Existem 5893 ruas com apenas um restaurante.

# %% [markdown]
# Foram encontradas 5893 ruas em LA com apenas um restaurante.

# %% [markdown]
# ### 3.9 - Para as ruas com muitos restaurantes, olhe para a distribuição de número de assentos. Quais tendências você consegue notar?

# %%
# filtro dados
popular_addresses = streets_with_most_restaurants['address']
popular_addresses = is_restaurant[is_restaurant['address'].isin(popular_addresses)]
popular_addresses
# Out:
#          id                           name                   address  chain  \
# 19    11805              delta sky club t3             300 world way  False
# 46    11832           the counter space 7c             700 world way   True
# 56    11842         loteria grill space 7c             700 world way  False
# 62    11848         rolling stone space 7c             700 world way  False
# 107   11893                  admirals club             400 world way  False
# 437   12223               arclight cinemas        6360 w sunset blvd  False
# 457   12243      usc main kitchen-basement       3607 trousdale pkwy   True
# 462   12248                 traditions pub       3607 trousdale pkwy  False
# 576   12362        jonathan club-bake shop         545 s figueroa st  False
# 579   12365        jonathan club cape code         545 s figueroa st  False
# 581   12367             employee cafeteria         545 s figueroa st   True
# 607   12393                    blue window             300 world way  False
# 667   12453                   dome theatre        6360 w sunset blvd  False
# 673   12459             level i concession        6360 w sunset blvd  False
# 686   12472           level ii concepssion        6360 w sunset blvd  False
# 863   12649                          verde       3607 trousdale pkwy  False
# 951   12737            juice it up - csula  5151 state university dr  False
# 954   12740                johny's kitchen  5151 state university dr  False
# 957   12743                      carl's jr  5151 state university dr   True
# 958   12744           kikka @ cal state la  5151 state university dr  False
# 959   12745            el pollo loco csula  5151 state university dr   True
# 963   12749                    rice garden  5151 state university dr   True
# 1495  13281                  jonathan club         545 s figueroa st  False
# 1510  13296                   buffet grill         545 s figueroa st  False
# 2461  14247        jw marriott los angeles        900 w olympic blvd  False
# 2696  14482         united airlines lounge             700 world way  False
# 2847  14633                       cafe 47'  5151 state university dr  False
# 3897  15683            the kitchen counter             600 world way   True
# 4073  15859                  espressamente        900 w olympic blvd  False
# 4273  16059                          blu20             600 world way  False
# 4279  16065              air canada lounge             600 world way  False
# 4378  16164  terminal 4 food court kitchen             400 world way   True
# 4450  16236     california gourmet kitchen             400 world way  False
# 4733  16519                          wp 24        900 w olympic blvd  False
# 4737  16523   level 2 banquet kitchen-cafe        900 w olympic blvd  False
# 5432  17218   the ritz carlton los angeles        900 w olympic blvd  False
# 5601  17387            virgin america loft             300 world way  False
# 6006  17792                gladstone's lax             300 world way  False
# 6132  17918   united air red carpet lounge             700 world way  False
# 6213  17999          el pollo loco/fosters  5151 state university dr   True
# 6311  18097                       lemonade       3607 trousdale pkwy   True
# 6669  18455                       tap room         545 s figueroa st  False
# 7012  18798                    the kitchen             600 world way   True
# 7120  18906          loteria bar and grill             700 world way   True
# 7147  18933               cph room service  2025 avenue of the stars  False
# 7148  18934                         breese  2025 avenue of the stars  False
# 7151  18937                   regency club  2025 avenue of the stars  False
# 7698  19484                      lemonades       3607 trousdale pkwy   True
# 7765  19551             cph kosher kitchen  2025 avenue of the stars  False
# 7813  19599                 cph kitchen #2  2025 avenue of the stars  False
# 7824  19610               cph/main kitchen  2025 avenue of the stars   True
# 8152  19938                     yogurtland             700 world way   True
# 8168  19954                         ruby's             600 world way  False
# 8207  19993          grilled cheese please             400 world way  False
# 8557  20343               la provence cafe             400 world way  False
# 8589  20375                food and bounty             400 world way   True
# 9399  21185        delta airline t3 lounge             300 world way  False
#
#             type  number
# 19    restaurant     103
# 46    restaurant      20
# 56    restaurant      17
# 62    restaurant      33
# 107   restaurant     118
# 437   restaurant     190
# 457   restaurant     227
# 462   restaurant     197
# 576   restaurant       5
# 579   restaurant      64
# 581   restaurant      33
# 607   restaurant      41
# 667   restaurant      15
# 673   restaurant       3
# 686   restaurant       9
# 863   restaurant      39
# 951   restaurant      23
# 954   restaurant      45
# 957   restaurant      32
# 958   restaurant      33
# 959   restaurant      29
# 963   restaurant      42
# 1495  restaurant     220
# 1510  restaurant     112
# 2461  restaurant     155
# 2696  restaurant     218
# 2847  restaurant      27
# 3897  restaurant       9
# 4073  restaurant       8
# 4273  restaurant      19
# 4279  restaurant     142
# 4378  restaurant      78
# 4450  restaurant      10
# 4733  restaurant     162
# 4737  restaurant       9
# 5432  restaurant      63
# 5601  restaurant     131
# 6006  restaurant      74
# 6132  restaurant     210
# 6213  restaurant      11
# 6311  restaurant     138
# 6669  restaurant     130
# 7012  restaurant      13
# 7120  restaurant      23
# 7147  restaurant     184
# 7148  restaurant     172
# 7151  restaurant      16
# 7698  restaurant     111
# 7765  restaurant       8
# 7813  restaurant      29
# 7824  restaurant     177
# 8152  restaurant      29
# 8168  restaurant      90
# 8207  restaurant      11
# 8557  restaurant      11
# 8589  restaurant      21
# 9399  restaurant     124

# %%
# construção gráfico linhas
plt.figure(figsize=(12,6))
sns.histplot(data=popular_addresses, x='number', hue='chain', alpha=0.6)
plt.title('Histogram Capacity per Establishment in popular addresses')
plt.xlabel('Capacity')
plt.ylabel('Establishments')
plt.show()

# %%
# construção boxplot
plt.figure(figsize=(12,6))
sns.boxplot(data=popular_addresses, y='number', x='chain', hue='chain')
plt.title('Boxplot distribuition sits per restaurant type')
plt.xlabel('Is Chain?')
plt.ylabel('Sits')
plt.show()

# %%
# construção boxplot
plt.figure(figsize=(12,6))
sns.scatterplot(data=popular_addresses, x='address', y='number', hue='chain')
plt.title('Scatterplot distribuition sits in popular addresses')
plt.xlabel('Addresses')
plt.ylabel('Sits')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# A maior parte destes restaurantes tendem a possuir capacidade pequena.
#
# Restaurantes que não fazem parte de uma rede tendem a possuir maior de capacidade.

# %% [markdown]
# ## 4. - Conclusão

# %% [markdown]
# ### 4.1 - Tire uma conclusão geral e apresente recomendações sobre o tipo mais apropriado de restaurante e o número de assentos. Comente sobre a possibilidade de desenvolver uma rede.

# %% [markdown]
# A análise do mercado de restaurantes em Los Angeles indica que o setor é altamente competitivo, com forte concentração no segmento de restaurantes tradicionais, enquanto cafés representam uma fatia menor (4.5%). Observa-se que estabelecimentos pertencentes a redes tendem a operar com menor número de assentos, enquanto negócios independentes concentram-se em operações maiores.
#
# A decisão pela abertura de um Café significa enfrentar concorrência relativamente inferior se comparada aos outros tipos de estabelecimento, o que é completamente plausível por se tratar de um projeto piloto. Em tese, um estabelecimento operado por robôs pode parecer mais eficiente, contudo apenas a experiência que pode validar esta máxima. Para menor margem de erros, recomenda-se trabalhar numa operação mais simples e enxuta, com preferência a um menor número de assentos.
# A possibilidade do desenvolvimento de uma rede passa diretamente pelo sucesso da primeira unidade, o que pode ser uma ótima maneira de escalar a ideia de negócio.

# %% [markdown]
# Presentation: <https://docs.google.com/presentation/d/1skcIXFCSW9MF5r0K3W7ngMB4Qc7ntceOudst5QLZRFk/edit?usp=sharing>
